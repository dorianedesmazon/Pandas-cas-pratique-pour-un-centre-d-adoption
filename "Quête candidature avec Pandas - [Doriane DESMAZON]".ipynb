# %% [markdown]
# # DATASET A NETTOYER

# %% [markdown]
# 1: Importe le fichier

# %%
import pandas as pd
# %matplotlib inline
import numpy as np
from matplotlib import pyplot
import matplotlib.pyplot as plt

path="/Users/doriane/Downloads/pandasdataset.xlsx"
df1=pd.read_excel(path, header=None)
df1
# Out:
#                         0                                                  1  \
# 0      dataset à nettoyer                                                NaN
# 1                  Prénom                                                Age
# 2                    Rana                                                 27
# 3                   Mioko                                                 24
# 4                  Prisca                                                 24
# 5                    Marc                                                 23
# 6                   Henri                                                 31
# 7                   Hanna                                                 25
# 8                  Samuel                                                 29
# 9                     Lee                                                 25
# 10                 Manuel                                                 25
# ...

# %% [markdown]
# 2 : Nettoie ton dataframe pour ne garder que les lignes 2 à 31, et les colonnes A à I

# %%
df1=df1[1:31]
df1
# Out:
#                 0    1            2                  3                  4  \
# 1          Prénom  Age  Taille en m  Pays de naissance  Pays de résidence
# 2            Rana   27         1.61             France             France
# 3           Mioko   24         1.49              Japan             France
# 4          Prisca   24          153      Côte d'ivoire             France
# 5            Marc   23         1.65             France             France
# 6           Henri   31         1.82             France             France
# 7           Hanna   25         3.45                 24             France
# 8          Samuel   29         1.75             France             France
# 9             Lee   25         1.66              Chine             France
# 10         Manuel   25         1.79            Mexique             France
# 11         Suk-Ho   24         1.71       Corée du Sud             France
# 12          Mioko   24         1.52              Japon             France
# ...

# %% [markdown]
# 3:Fais en sorte que les noms des colonnes correspondent aux intitulés de la ligne 2

# %%
df1=df1.reset_index(drop=True)
df1
# Out:
#                 0    1            2                  3                  4  \
# 0          Prénom  Age  Taille en m  Pays de naissance  Pays de résidence
# 1            Rana   27         1.61             France             France
# 2           Mioko   24         1.49              Japan             France
# 3          Prisca   24          153      Côte d'ivoire             France
# 4            Marc   23         1.65             France             France
# 5           Henri   31         1.82             France             France
# 6           Hanna   25         3.45                 24             France
# 7          Samuel   29         1.75             France             France
# 8             Lee   25         1.66              Chine             France
# 9          Manuel   25         1.79            Mexique             France
# 10         Suk-Ho   24         1.71       Corée du Sud             France
# 11          Mioko   24         1.52              Japon             France
# ...

# %%
header=df1.iloc[0]
print(header)
# Out:
# 0                          Prénom
# 1                             Age
# 2                     Taille en m
# 3               Pays de naissance
# 4               Pays de résidence
# 5                Type de logement
# 6    Nombre d’animal de compagnie
# 7             Salaire mensuel net
# 8    Années d’études après le Bac
# Name: 0, dtype: object

# %%
df1=df1[1:]
df1
# Out:
#                 0    1     2                 3       4                  5   6  \
# 1            Rana   27  1.61            France  France        Appartement   0
# 2           Mioko   24  1.49             Japan  France        Appartement  -3
# 3          Prisca   24   153     Côte d'ivoire  France  Logement étudiant   0
# 4            Marc   23  1.65            France  France  Logement étudiant   0
# 5           Henri   31  1.82            France  France        Appartement   1
# 6           Hanna   25  3.45                24  France             Maison   5
# 7          Samuel   29  1.75            France  France             Maison   1
# 8             Lee   25  1.66             Chine  France             Studio   A
# 9          Manuel   25  1.79           Mexique  France             Maison   0
# 10         Suk-Ho   24  1.71      Corée du Sud  France        Appartement   0
# 11          Mioko   24  1.52             Japon  France             Maison   0
# ...

# %%
df1=df1.reset_index(drop=True)
df1
# Out:
#                 0    1     2                 3       4                  5   6  \
# 0            Rana   27  1.61            France  France        Appartement   0
# 1           Mioko   24  1.49             Japan  France        Appartement  -3
# 2          Prisca   24   153     Côte d'ivoire  France  Logement étudiant   0
# 3            Marc   23  1.65            France  France  Logement étudiant   0
# 4           Henri   31  1.82            France  France        Appartement   1
# 5           Hanna   25  3.45                24  France             Maison   5
# 6          Samuel   29  1.75            France  France             Maison   1
# 7             Lee   25  1.66             Chine  France             Studio   A
# 8          Manuel   25  1.79           Mexique  France             Maison   0
# 9          Suk-Ho   24  1.71      Corée du Sud  France        Appartement   0
# 10          Mioko   24  1.52             Japon  France             Maison   0
# ...

# %%
df1=df1.rename(columns=header)
df1
# Out:
#            Prénom  Age Taille en m Pays de naissance Pays de résidence  \
# 0            Rana   27        1.61            France            France
# 1           Mioko   24        1.49             Japan            France
# 2          Prisca   24         153     Côte d'ivoire            France
# 3            Marc   23        1.65            France            France
# 4           Henri   31        1.82            France            France
# 5           Hanna   25        3.45                24            France
# 6          Samuel   29        1.75            France            France
# 7             Lee   25        1.66             Chine            France
# 8          Manuel   25        1.79           Mexique            France
# 9          Suk-Ho   24        1.71      Corée du Sud            France
# 10          Mioko   24        1.52             Japon            France
# 11           Jung   21        1.69  Corée de l’Ouest            France
# ...

# %% [markdown]
# 4:Propose 3 visualisations pour repérer les outliers

# %%
pyplot.plot(df1['Années d’études après le Bac'],'bo')
pyplot.grid(True)

# %%
ax = df1['Age'].plot.hist(bins=20)

# %%
pyplot.plot(df1['Salaire mensuel net'],'bo')
pyplot.grid(True)

# %% [markdown]
# 5:Mets les colonnes au bon type

# %%
df1["Prénom"].astype('str')
df1["Age"].astype('str')
df1["Pays de naissance"].astype('str')
df1["Pays de résidence"].astype('str')
df1["Type de logement"].astype('str')
df1[['Age','Taille en m','Salaire mensuel net','Années d’études après le Bac']]=df1[['Age','Taille en m','Salaire mensuel net','Années d’études après le Bac']].apply(pd.to_numeric)

# %%
df1.dtypes
# Out:
# Prénom                           object
# Age                               int64
# Taille en m                     float64
# Pays de naissance                object
# Pays de résidence                object
# Type de logement                 object
# Nombre d’animal de compagnie     object
# Salaire mensuel net               int64
# Années d’études après le Bac      int64
# dtype: object

# %% [markdown]
# # DATASET A EXPLORER

# %% [markdown]
# 1: Importe le fichier

# %%
path="/Users/doriane/Downloads/datasetexplorer.csv"
df3=pd.read_csv(path, sep=";", encoding="utf8", error_bad_lines=False)
df3
# Out:
#     dataset à explorer Unnamed: 1           Unnamed: 2         Unnamed: 3  \
# 0               Prénom        Age  Situation familiale  Pays de naissance
# 1              Jasmine         32                Marié    Grande Bretagne
# 2                Sakho         21          Célibataire       Corée du Sud
# 3               Hélène         24          Célibataire             France
# 4              Roberto         27                Marié            Espagne
# 5               Benoit         35                Marié             France
# 6                 Igor         29                Marié             Russie
# 7                Mioko         22          Célibataire              Japon
# 8                 Jung         21                Marié              Chine
# 9                 Toby         34          Célibataire    Grande Bretagne
# 10                Loïc         33                Marié             France
# 11             Magalie         35          Célibataire             France
# ...

# %% [markdown]
# 2: Ne conserve que les lignes 1 à 16 et les colonnes A à I

# %%
df4=df3[['dataset à explorer', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3','Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']]
df4
# Out:
#     dataset à explorer Unnamed: 1           Unnamed: 2         Unnamed: 3  \
# 0               Prénom        Age  Situation familiale  Pays de naissance
# 1              Jasmine         32                Marié    Grande Bretagne
# 2                Sakho         21          Célibataire       Corée du Sud
# 3               Hélène         24          Célibataire             France
# 4              Roberto         27                Marié            Espagne
# 5               Benoit         35                Marié             France
# 6                 Igor         29                Marié             Russie
# 7                Mioko         22          Célibataire              Japon
# 8                 Jung         21                Marié              Chine
# 9                 Toby         34          Célibataire    Grande Bretagne
# 10                Loïc         33                Marié             France
# 11             Magalie         35          Célibataire             France
# ...

# %%
df4=df4[0:15]
df4
# Out:
#    dataset à explorer Unnamed: 1           Unnamed: 2         Unnamed: 3  \
# 0              Prénom        Age  Situation familiale  Pays de naissance
# 1             Jasmine         32                Marié    Grande Bretagne
# 2               Sakho         21          Célibataire       Corée du Sud
# 3              Hélène         24          Célibataire             France
# 4             Roberto         27                Marié            Espagne
# 5              Benoit         35                Marié             France
# 6                Igor         29                Marié             Russie
# 7               Mioko         22          Célibataire              Japon
# 8                Jung         21                Marié              Chine
# 9                Toby         34          Célibataire    Grande Bretagne
# 10               Loïc         33                Marié             France
# 11            Magalie         35          Célibataire             France
# ...

# %% [markdown]
# 3: Fais en sorte que les noms des colonnes correspondent aux intitulés de la ligne 2

# %%
header2=df4.iloc[0]
print(header2)
# Out:
# dataset à explorer                           Prénom
# Unnamed: 1                                      Age
# Unnamed: 2                      Situation familiale
# Unnamed: 3                        Pays de naissance
# Unnamed: 4                        Pays de résidence
# Unnamed: 5                         Type de logement
# Unnamed: 6            Nombre d’animaux de compagnie
# Unnamed: 7                      Salaire mensuel net
# Unnamed: 8             Années d’études après le Bac
# Name: 0, dtype: object

# %%
df4=df4[1:]
df4
# Out:
#    dataset à explorer Unnamed: 1   Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 1             Jasmine         32        Marié  Grande Bretagne     France
# 2               Sakho         21  Célibataire     Corée du Sud     France
# 3              Hélène         24  Célibataire           France     France
# 4             Roberto         27        Marié          Espagne     France
# 5              Benoit         35        Marié           France     France
# 6                Igor         29        Marié           Russie     France
# 7               Mioko         22  Célibataire            Japon     France
# 8                Jung         21        Marié            Chine     France
# 9                Toby         34  Célibataire  Grande Bretagne     France
# 10               Loïc         33        Marié           France     France
# 11            Magalie         35  Célibataire           France     France
# 12            Giovani         25        Marié           Italie     France
# ...

# %%
df4=df4.reset_index(drop=True)
df4
# Out:
#    dataset à explorer Unnamed: 1   Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 0             Jasmine         32        Marié  Grande Bretagne     France
# 1               Sakho         21  Célibataire     Corée du Sud     France
# 2              Hélène         24  Célibataire           France     France
# 3             Roberto         27        Marié          Espagne     France
# 4              Benoit         35        Marié           France     France
# 5                Igor         29        Marié           Russie     France
# 6               Mioko         22  Célibataire            Japon     France
# 7                Jung         21        Marié            Chine     France
# 8                Toby         34  Célibataire  Grande Bretagne     France
# 9                Loïc         33        Marié           France     France
# 10            Magalie         35  Célibataire           France     France
# 11            Giovani         25        Marié           Italie     France
# ...

# %%
df4.columns=header2
df4
# Out:
# 0    Prénom Age Situation familiale Pays de naissance Pays de résidence  \
# 0   Jasmine  32               Marié   Grande Bretagne            France
# 1     Sakho  21         Célibataire      Corée du Sud            France
# 2    Hélène  24         Célibataire            France            France
# 3   Roberto  27               Marié           Espagne            France
# 4    Benoit  35               Marié            France            France
# 5      Igor  29               Marié            Russie            France
# 6     Mioko  22         Célibataire             Japon            France
# 7      Jung  21               Marié             Chine            France
# 8      Toby  34         Célibataire   Grande Bretagne            France
# 9      Loïc  33               Marié            France            France
# 10  Magalie  35         Célibataire            France            France
# 11  Giovani  25               Marié            Italie            France
# ...

# %%
#Il y a un pb avec nombre d'animaux de compagnie donc on change pour "Animaux"
df4.rename(columns={"Nombre d’animaux de compagnie":'Animaux'}, inplace=True)
df4
# Out:
# 0    Prénom Age Situation familiale Pays de naissance Pays de résidence  \
# 0   Jasmine  32               Marié   Grande Bretagne            France
# 1     Sakho  21         Célibataire      Corée du Sud            France
# 2    Hélène  24         Célibataire            France            France
# 3   Roberto  27               Marié           Espagne            France
# 4    Benoit  35               Marié            France            France
# 5      Igor  29               Marié            Russie            France
# 6     Mioko  22         Célibataire             Japon            France
# 7      Jung  21               Marié             Chine            France
# 8      Toby  34         Célibataire   Grande Bretagne            France
# 9      Loïc  33               Marié            France            France
# 10  Magalie  35         Célibataire            France            France
# 11  Giovani  25               Marié            Italie            France
# ...

# %% [markdown]
# 4: Mets les colonnes au bon type

# %%
df4[['Age','Salaire mensuel net','Animaux']]=df4[['Age','Salaire mensuel net','Animaux']].apply(pd.to_numeric)
df4.dtypes
# Out:
# 0
# Prénom                          object
# Age                              int64
# Situation familiale             object
# Pays de naissance               object
# Pays de résidence               object
# Type de logement                object
# Animaux                          int64
# Salaire mensuel net              int64
# Années d’études après le Bac    object
# dtype: object

# %% [markdown]
# 5: Propose 5 type de visualisation

# %%
df4.plot.scatter(x='Age',y='Animaux',s=df4['Salaire mensuel net'])

# %%
df4.hist(column='Animaux',by='Situation familiale')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10f4dec88>,
# ...
#       dtype=object)

# %%
df4['Type de logement'].value_counts().plot.pie()

# %% [markdown]
# 6: Réponds aux questions de l'énoncé

# %%
#Quelle est la valeur médiane pour chacune des colonnes ?
df4[['Age','Animaux','Salaire mensuel net']].median()
# Out:
# 0
# Age                      28.0
# Animaux                   1.0
# Salaire mensuel net    2394.5
# dtype: float64

# %%
#Calculer l’écart type des colonnes numériques
df4[['Age','Animaux','Salaire mensuel net']].std(ddof = 0)
# Out:
# 0
# Age                      5.790562
# Animaux                  1.263700
# Salaire mensuel net    910.076483
# dtype: float64

# %%
#Quelle est la moyenne du nombre d’animaux de compagnie ?
df4['Animaux'].mean()
# Out:
# 1.2142857142857142

# %%
#Quel est le mode de la colonne « Situation familiale » ?
df4['Situation familiale'].mode()
# Out:
# 0    Marié
# dtype: object

# %%
#Calculer la valeur moyenne de la colonne « Salaire mensuel net » ?
df4['Salaire mensuel net'].mean()
# Out:
# 2446.285714285714

# %%
#Pour la colonne « Salaire mensuel net », la moyenne est-elle égale à la médiane ?

if df4['Salaire mensuel net'].mean()==df4['Salaire mensuel net'].median():
    print('égal')
else:
    print('non égal')
# Out:
# non égal

# %%
#Si on exclu Toby, quel groupe distinct d’années d’études a le plus haut salaire moyen, médian ?
df4.iat[8,7]=0
df4.groupby(["Années d’études après le Bac"]).mean()
# Out:
# 0                               Age  Animaux  Salaire mensuel net
# Années d’études après le Bac
# 2                             27.40     0.80              1826.20
# 3                             25.75     1.25              2208.25
# 5                             31.00     2.00              3046.00
# 7                             34.00     0.00                 0.00

# %%
#Si on exclu Toby, quel groupe distinct d’années d’études a le plus haut salaire moyen, médian ?
df4.iat[8,7]=4100

# %%
#D’après vous, parmi les 6 personnes qui n'ont pas d'animal, qui est le plus susceptible d'en adopter un ? Pourquoi ?
